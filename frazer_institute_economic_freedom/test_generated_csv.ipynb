# %%
import pandas as pd

# %%
economic_freedom_df = pd.read_csv("./economic-freedom-of-the-world-data-for-researchers.csv")

economic_freedom_df.head()
# Out:
#    Year ISO_Code    Countries  Economic Freedom Summary Index  \
# 0  2014      HKG    Hong Kong                            9.03
# 1  2014      SGP    Singapore                            8.71
# 2  2014      NZL  New Zealand                            8.35
# 3  2014      CHE  Switzerland                            8.25
# 4  2014      CAN       Canada                            7.98
#
#    Government Consumption  1A data  Transfers and subsidies  1B data  \
# 0                    8.08    12.54                     9.17     3.55
# 1                    5.46    21.44                     8.85     4.71
# 2                    4.40    25.05                     6.17    14.56
# 3                    6.79    16.90                     6.03    15.08
# 4                    3.68    27.50                     7.61     9.26
#
#    Government enterprises and investment  1C data     ...      Conscription  \
# 0                                   10.0    12.62     ...              10.0
# ...

# %%
len(economic_freedom_df[economic_freedom_df["Year"] == 2016])
# Out:
# 0

# %%
len(economic_freedom_df[economic_freedom_df["Year"] == 2014])
# Out:
# 159
